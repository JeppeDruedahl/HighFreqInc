# %% [markdown]
# # Imports

# %%
# %load_ext autoreload
# %autoreload 2

# generic
import time
import itertools as it
import numpy as np

import matplotlib.pyplot as plt
plt.style.use('seaborn')
colors = [x['color'] for x in plt.style.library['seaborn']['axes.prop_cycle']]
plt.close('all')

# load the model module
from HighFreqIncProcess import HighFreqIncProcessClass

# %% [markdown]
# # Setup

# %%
# a. setup
par = {'use_equal_weighting':True,'use_theoretical':False}
model = HighFreqIncProcessClass(name='checks',par=par)
model.set_specs()

tmodel = model.copy(par={'use_theoretical':True})

# b. print (baseline parametrization)
print('')
print(model)
# Out:
# Modelclass: HighFreqIncProcessClass
# Name: checks
#
# namespaces: ['par', 'sim', 'sol']
# other_attrs: ['latexname', 'specs', 'theta', 'data', 'datamoms', 'moms', 'est']
# savefolder: saved
# not_floats: ['simT', 'simQ', 'simN', 'Nmoms', 'Ndata', 'use_equal_weighting', 'use_theoretical', 'est_max_iter', 'est_max_iter_ini', 'N_guesses', 'N_identification', 'N_multistart', 'seed', 'seed_sim', 'do_d1ky', 'do_d12ky', 'kmax', 'Nomegas_cond']
#
# par:
#  simT = 360 [int]
#  simN = 100000 [int]
#  p_psi = 0.05 [float]
#  p_xi = 0.08 [float]
#  p_phi = 0.1 [float]
#  p_eta = 0.15 [float]
#  rho = 0.9 [float]
#  sigma_psi = 0.15 [float]
#  sigma_xi = 0.2 [float]
#  sigma_phi = 0.05 [float]
#  sigma_eta = 0.02 [float]
#  sigma_epsilon = 0.0 [float]
#  mu_phi = 0.02 [float]
#  mu_xi = 0.3 [float]
#  mu_eta = 0.0 [float]
#  Nmoms = 0 [int]
#  Ndata = 0 [int]
#  use_equal_weighting = True
#  use_theoretical = False
#  est_method = Nelder-Mead+BFGS [str]
#  est_tol = 1e-08 [float]
#  est_max_iter = 10000 [int]
#  est_max_iter_ini = 500 [int]
#  N_guesses = 500 [int]
#  wtrue = 0.99 [float]
#  N_identification = 500 [int]
#  N_multistart = 50 [int]
#  seed = 2019 [int]
#  seed_sim = 17 [int]
#  do_d1ky = True
#  do_d12ky = True
#  kmax = 6 [int]
#  wmin = 1e-06 [float]
#  omega_cond_midrange = 0.01 [float]
#  omegas_cond = ndarray with shape = (6,) [dtype: float64]
#  Nomegas_cond = 6 [int]
#  omegas_cdf = ndarray with shape = (0,) [dtype: float64]
#  cov_moms = ndarray with shape = (0, 0) [dtype: float64]
#  W = ndarray with shape = (0, 0) [dtype: float64]
#  Ypsilon = ndarray with shape = (0, 0) [dtype: float64]
#  w_psi = ndarray with shape = (0,) [dtype: float64]
#  w_xi = ndarray with shape = (0,) [dtype: float64]
#  w_phi = ndarray with shape = (0,) [dtype: float64]
#  w_eta = ndarray with shape = (0,) [dtype: float64]
#  memory, gb: 0.0
#
# sim:
#  y = ndarray with shape = (0, 0) [dtype: float64]
#  p = ndarray with shape = (0, 0) [dtype: float64]
#  z = ndarray with shape = (0, 0) [dtype: float64]
#  p_psi = ndarray with shape = (0, 0) [dtype: float64]
#  p_xi = ndarray with shape = (0, 0) [dtype: float64]
#  p_phi = ndarray with shape = (0, 0) [dtype: float64]
#  p_eta = ndarray with shape = (0, 0) [dtype: float64]
#  psi_raw = ndarray with shape = (0, 0) [dtype: float64]
#  xi_raw = ndarray with shape = (0, 0) [dtype: float64]
#  phi_raw = ndarray with shape = (0, 0) [dtype: float64]
#  eta_raw = ndarray with shape = (0, 0) [dtype: float64]
#  epsilon_raw = ndarray with shape = (0, 0) [dtype: float64]
#  p0_raw = ndarray with shape = (0,) [dtype: float64]
#  d1ky = ndarray with shape = (0, 0, 0) [dtype: float64]
#  d1kyw = ndarray with shape = (0, 0, 0) [dtype: float64]
#  d1ky_lag = ndarray with shape = (0, 0, 0) [dtype: float64]
#  d12ky = ndarray with shape = (0, 0, 0) [dtype: float64]
#  d12kyw = ndarray with shape = (0, 0, 0) [dtype: float64]
#  d12ky_lag = ndarray with shape = (0, 0, 0) [dtype: float64]
#  memory, gb: 0.0
#
# sol:
#  memory, gb: 0.0

# %% [markdown]
# **Calculate theoretical moments:**

# %%
tmodel.calc_moments()
# %timeit tmodel.calc_moments()
# Out:
# 118 ms ± 829 µs per loop (mean ± std. dev. of 7 runs, 10 loops each)

# %% [markdown]
# **Calculate simulated moments:**

# %%
# %time model.setup_simulation()
# %time model.simulate()
# Out:
# Wall time: 21.9 s
# Wall time: 7.11 s

# %%
# %time model.calc_moments()
# Out:
# Wall time: 29.9 s

# %% [markdown]
# # Comparison

# %%
model.compare_moments(tmodel,str_self='simultation',str_other='theoretical')
# Out:
# mean_d12ky [1]                          : simultation =  0.0241, theoretical =  0.0240 diff =  0.0001
# var_d12ky [1]                           : simultation =  0.0370, theoretical =  0.0370 diff = -0.0000
# kurt_d12ky [1]                          : simultation =  3.5945, theoretical =  3.5922 diff =  0.0023
# mean_d12ky [2]                          : simultation =  0.0482, theoretical =  0.0480 diff =  0.0002
# var_d12ky [2]                           : simultation =  0.0534, theoretical =  0.0535 diff = -0.0001
# kurt_d12ky [2]                          : simultation =  1.9659, theoretical =  1.9629 diff =  0.0030
# mean_d12ky [3]                          : simultation =  0.0724, theoretical =  0.0720 diff =  0.0004
# var_d12ky [3]                           : simultation =  0.0691, theoretical =  0.0692 diff = -0.0001
# kurt_d12ky [3]                          : simultation =  1.2919, theoretical =  1.2836 diff =  0.0083
# mean_d12ky [4]                          : simultation =  0.0966, theoretical =  0.0960 diff =  0.0006
# var_d12ky [4]                           : simultation =  0.0841, theoretical =  0.0841 diff = -0.0001
# kurt_d12ky [4]                          : simultation =  0.9301, theoretical =  0.9224 diff =  0.0077
# mean_d12ky [5]                          : simultation =  0.1208, theoretical =  0.1200 diff =  0.0008
# var_d12ky [5]                           : simultation =  0.0983, theoretical =  0.0984 diff = -0.0001
# kurt_d12ky [5]                          : simultation =  0.7098, theoretical =  0.7029 diff =  0.0070
# mean_d12ky [6]                          : simultation =  0.1450, theoretical =  0.1440 diff =  0.0010
# var_d12ky [6]                           : simultation =  0.1120, theoretical =  0.1121 diff = -0.0001
# kurt_d12ky [6]                          : simultation =  0.5643, theoretical =  0.5566 diff =  0.0077
# auto_cov_d12y12l [1]                    : simultation = -0.0103, theoretical = -0.0103 diff = -0.0000
# auto_cov_d12y12l [2]                    : simultation = -0.0004, theoretical = -0.0004 diff =  0.0000
# auto_cov_d12y12l [3]                    : simultation = -0.0003, theoretical = -0.0004 diff =  0.0000
# auto_cov_d12y12l [4]                    : simultation = -0.0003, theoretical = -0.0003 diff = -0.0000
# auto_cov_d12y12l [5]                    : simultation = -0.0003, theoretical = -0.0003 diff = -0.0000
# auto_cov_d12y12l [6]                    : simultation = -0.0003, theoretical = -0.0003 diff =  0.0000
# auto_cov_d12y12l [7]                    : simultation = -0.0003, theoretical = -0.0003 diff =  0.0000
# auto_cov_d12y12l [8]                    : simultation = -0.0003, theoretical = -0.0003 diff =  0.0000
# frac_auto_cov_d12y1l [1]                : simultation =  0.0158, theoretical =  0.0158 diff = -0.0000
# frac_auto_cov_d12y1l [2]                : simultation =  0.0143, theoretical =  0.0143 diff = -0.0000
# frac_auto_cov_d12y1l [3]                : simultation =  0.0128, theoretical =  0.0128 diff = -0.0000
# frac_auto_cov_d12y1l [4]                : simultation =  0.0113, theoretical =  0.0114 diff = -0.0000
# frac_auto_cov_d12y1l [5]                : simultation =  0.0099, theoretical =  0.0099 diff = -0.0000
# frac_auto_cov_d12y1l [6]                : simultation =  0.0084, theoretical =  0.0084 diff = -0.0000
# frac_auto_cov_d12y1l [7]                : simultation =  0.0069, theoretical =  0.0070 diff = -0.0000
# frac_auto_cov_d12y1l [8]                : simultation =  0.0055, theoretical =  0.0055 diff = -0.0000
# frac_auto_cov_d12y1l [9]                : simultation =  0.0040, theoretical =  0.0040 diff = -0.0000
# frac_auto_cov_d12y1l [10]               : simultation =  0.0025, theoretical =  0.0025 diff = -0.0000
# frac_auto_cov_d12y1l [11]               : simultation =  0.0011, theoretical =  0.0011 diff = -0.0000
# leq_d1ky [(1, 0.5)]                     : simultation =  0.9876, theoretical =  0.9876 diff = -0.0000
# leq_d1ky [(1, 0.4)]                     : simultation =  0.9761, theoretical =  0.9761 diff =  0.0000
# leq_d1ky [(1, 0.3)]                     : simultation =  0.9607, theoretical =  0.9607 diff =  0.0000
# leq_d1ky [(1, 0.2)]                     : simultation =  0.9426, theoretical =  0.9426 diff = -0.0000
# leq_d1ky [(1, 0.1)]                     : simultation =  0.9180, theoretical =  0.9181 diff = -0.0000
# leq_d1ky [(1, 0.05)]                    : simultation =  0.8881, theoretical =  0.8881 diff = -0.0000
# leq_d1ky [(1, 0.04)]                    : simultation =  0.8767, theoretical =  0.8767 diff = -0.0000
# leq_d1ky [(1, 0.03)]                    : simultation =  0.8594, theoretical =  0.8594 diff = -0.0000
# leq_d1ky [(1, 0.02)]                    : simultation =  0.8325, theoretical =  0.8325 diff =  0.0000
# leq_d1ky [(1, 0.01)]                    : simultation =  0.7945, theoretical =  0.7945 diff =  0.0000
# leq_d1ky [(1, 0.005)]                   : simultation =  0.7722, theoretical =  0.7721 diff =  0.0001
# leq_d1ky [(1, 0.001)]                   : simultation =  0.7535, theoretical =  0.7535 diff =  0.0000
# leq_d1ky [(1, 0.0001)]                  : simultation =  0.7493, theoretical =  0.7492 diff =  0.0000
# leq_d1ky [(1, -0.0001)]                 : simultation =  0.2254, theoretical =  0.2254 diff = -0.0000
# leq_d1ky [(1, -0.001)]                  : simultation =  0.2212, theoretical =  0.2212 diff = -0.0000
# leq_d1ky [(1, -0.005)]                  : simultation =  0.2026, theoretical =  0.2026 diff = -0.0000
# leq_d1ky [(1, -0.01)]                   : simultation =  0.1806, theoretical =  0.1806 diff = -0.0000
# leq_d1ky [(1, -0.02)]                   : simultation =  0.1438, theoretical =  0.1439 diff = -0.0000
# leq_d1ky [(1, -0.03)]                   : simultation =  0.1189, theoretical =  0.1190 diff = -0.0000
# leq_d1ky [(1, -0.04)]                   : simultation =  0.1041, theoretical =  0.1041 diff = -0.0000
# leq_d1ky [(1, -0.05)]                   : simultation =  0.0955, theoretical =  0.0955 diff = -0.0000
# leq_d1ky [(1, -0.1)]                    : simultation =  0.0771, theoretical =  0.0771 diff = -0.0000
# leq_d1ky [(1, -0.2)]                    : simultation =  0.0566, theoretical =  0.0566 diff = -0.0000
# leq_d1ky [(1, -0.3)]                    : simultation =  0.0387, theoretical =  0.0387 diff = -0.0000
# leq_d1ky [(1, -0.4)]                    : simultation =  0.0234, theoretical =  0.0234 diff = -0.0000
# leq_d1ky [(1, -0.5)]                    : simultation =  0.0121, theoretical =  0.0121 diff =  0.0000
# leq_d1ky_midrange [(1, 0.5)]            : simultation =  0.9868, theoretical =  0.9868 diff = -0.0000
# leq_d1ky_midrange [(1, 0.3)]            : simultation =  0.9585, theoretical =  0.9584 diff =  0.0000
# leq_d1ky_midrange [(1, 0.1)]            : simultation =  0.9157, theoretical =  0.9157 diff = -0.0000
# leq_d1ky_midrange [(1, 0.05)]           : simultation =  0.8862, theoretical =  0.8862 diff = -0.0000
# leq_d1ky_midrange [(1, 0.01)]           : simultation =  0.8150, theoretical =  0.8149 diff =  0.0001
# leq_d1ky_midrange [(1, 0.001)]          : simultation =  0.7682, theoretical =  0.7682 diff =  0.0000
# leq_d1ky_midrange [(1, 0.0001)]         : simultation =  0.7633, theoretical =  0.7633 diff =  0.0000
# leq_d1ky_midrange [(1, -0.0001)]        : simultation =  0.1405, theoretical =  0.1405 diff = -0.0001
# leq_d1ky_midrange [(1, -0.001)]         : simultation =  0.1357, theoretical =  0.1357 diff = -0.0000
# leq_d1ky_midrange [(1, -0.01)]          : simultation =  0.0894, theoretical =  0.0895 diff = -0.0000
# leq_d1ky_midrange [(1, -0.05)]          : simultation =  0.0287, theoretical =  0.0287 diff = -0.0000
# leq_d1ky_midrange [(1, -0.1)]           : simultation =  0.0147, theoretical =  0.0148 diff = -0.0000
# leq_d1ky_midrange [(1, -0.3)]           : simultation =  0.0015, theoretical =  0.0015 diff = -0.0000
# leq_d1ky_midrange [(1, -0.5)]           : simultation =  0.0001, theoretical =  0.0001 diff =  0.0000
# leq_d12ky [(1, 0.5)]                    : simultation =  0.9803, theoretical =  0.9802 diff =  0.0000
# leq_d12ky [(1, 0.4)]                    : simultation =  0.9631, theoretical =  0.9631 diff = -0.0000
# leq_d12ky [(1, 0.3)]                    : simultation =  0.9328, theoretical =  0.9328 diff =  0.0000
# leq_d12ky [(1, 0.2)]                    : simultation =  0.8765, theoretical =  0.8765 diff = -0.0001
# leq_d12ky [(1, 0.1)]                    : simultation =  0.7536, theoretical =  0.7537 diff = -0.0001
# leq_d12ky [(1, 0.05)]                   : simultation =  0.6312, theoretical =  0.6314 diff = -0.0002
# leq_d12ky [(1, 0.04)]                   : simultation =  0.6007, theoretical =  0.6010 diff = -0.0002
# leq_d12ky [(1, 0.03)]                   : simultation =  0.5684, theoretical =  0.5686 diff = -0.0002
# leq_d12ky [(1, 0.02)]                   : simultation =  0.5341, theoretical =  0.5342 diff = -0.0001
# leq_d12ky [(1, 0.01)]                   : simultation =  0.4980, theoretical =  0.4982 diff = -0.0002
# leq_d12ky [(1, 0.005)]                  : simultation =  0.4797, theoretical =  0.4799 diff = -0.0002
# leq_d12ky [(1, 0.001)]                  : simultation =  0.4651, theoretical =  0.4653 diff = -0.0002
# leq_d12ky [(1, 0.0001)]                 : simultation =  0.4618, theoretical =  0.4621 diff = -0.0003
# leq_d12ky [(1, -0.0001)]                : simultation =  0.3677, theoretical =  0.3680 diff = -0.0003
# leq_d12ky [(1, -0.001)]                 : simultation =  0.3645, theoretical =  0.3648 diff = -0.0003
# leq_d12ky [(1, -0.005)]                 : simultation =  0.3503, theoretical =  0.3506 diff = -0.0003
# leq_d12ky [(1, -0.01)]                  : simultation =  0.3332, theoretical =  0.3335 diff = -0.0003
# leq_d12ky [(1, -0.02)]                  : simultation =  0.3017, theoretical =  0.3019 diff = -0.0002
# leq_d12ky [(1, -0.03)]                  : simultation =  0.2744, theoretical =  0.2746 diff = -0.0002
# leq_d12ky [(1, -0.04)]                  : simultation =  0.2512, theoretical =  0.2513 diff = -0.0002
# leq_d12ky [(1, -0.05)]                  : simultation =  0.2313, theoretical =  0.2314 diff = -0.0001
# leq_d12ky [(1, -0.1)]                   : simultation =  0.1625, theoretical =  0.1627 diff = -0.0002
# leq_d12ky [(1, -0.2)]                   : simultation =  0.0901, theoretical =  0.0901 diff = -0.0001
# leq_d12ky [(1, -0.3)]                   : simultation =  0.0498, theoretical =  0.0498 diff = -0.0000
# leq_d12ky [(1, -0.4)]                   : simultation =  0.0270, theoretical =  0.0271 diff = -0.0001
# leq_d12ky [(1, -0.5)]                   : simultation =  0.0141, theoretical =  0.0141 diff = -0.0000
# leq_d12ky [(2, 0.5)]                    : simultation =  0.9668, theoretical =  0.9668 diff =  0.0001
# leq_d12ky [(2, 0.4)]                    : simultation =  0.9380, theoretical =  0.9380 diff =  0.0000
# leq_d12ky [(2, 0.3)]                    : simultation =  0.8862, theoretical =  0.8862 diff =  0.0000
# leq_d12ky [(2, 0.2)]                    : simultation =  0.7941, theoretical =  0.7942 diff = -0.0002
# leq_d12ky [(2, 0.1)]                    : simultation =  0.6334, theoretical =  0.6336 diff = -0.0003
# leq_d12ky [(2, 0.05)]                   : simultation =  0.5188, theoretical =  0.5192 diff = -0.0005
# leq_d12ky [(2, 0.04)]                   : simultation =  0.4940, theoretical =  0.4944 diff = -0.0004
# leq_d12ky [(2, 0.03)]                   : simultation =  0.4689, theoretical =  0.4692 diff = -0.0003
# leq_d12ky [(2, 0.02)]                   : simultation =  0.4436, theoretical =  0.4440 diff = -0.0004
# leq_d12ky [(2, 0.01)]                   : simultation =  0.4185, theoretical =  0.4189 diff = -0.0004
# leq_d12ky [(2, 0.005)]                  : simultation =  0.4061, theoretical =  0.4064 diff = -0.0003
# leq_d12ky [(2, 0.001)]                  : simultation =  0.3963, theoretical =  0.3966 diff = -0.0004
# leq_d12ky [(2, 0.0001)]                 : simultation =  0.3941, theoretical =  0.3945 diff = -0.0004
# leq_d12ky [(2, -0.0001)]                : simultation =  0.3793, theoretical =  0.3797 diff = -0.0004
# leq_d12ky [(2, -0.001)]                 : simultation =  0.3772, theoretical =  0.3775 diff = -0.0004
# leq_d12ky [(2, -0.005)]                 : simultation =  0.3676, theoretical =  0.3680 diff = -0.0004
# leq_d12ky [(2, -0.01)]                  : simultation =  0.3558, theoretical =  0.3563 diff = -0.0005
# leq_d12ky [(2, -0.02)]                  : simultation =  0.3335, theoretical =  0.3339 diff = -0.0004
# leq_d12ky [(2, -0.03)]                  : simultation =  0.3126, theoretical =  0.3131 diff = -0.0004
# leq_d12ky [(2, -0.04)]                  : simultation =  0.2934, theoretical =  0.2938 diff = -0.0004
# leq_d12ky [(2, -0.05)]                  : simultation =  0.2757, theoretical =  0.2760 diff = -0.0004
# leq_d12ky [(2, -0.1)]                   : simultation =  0.2041, theoretical =  0.2045 diff = -0.0004
# leq_d12ky [(2, -0.2)]                   : simultation =  0.1138, theoretical =  0.1140 diff = -0.0002
# leq_d12ky [(2, -0.3)]                   : simultation =  0.0619, theoretical =  0.0620 diff = -0.0002
# leq_d12ky [(2, -0.4)]                   : simultation =  0.0330, theoretical =  0.0331 diff = -0.0002
# leq_d12ky [(2, -0.5)]                   : simultation =  0.0172, theoretical =  0.0173 diff = -0.0001
# leq_d12ky [(3, 0.5)]                    : simultation =  0.9471, theoretical =  0.9471 diff =  0.0001
# leq_d12ky [(3, 0.4)]                    : simultation =  0.9047, theoretical =  0.9047 diff =  0.0000
# leq_d12ky [(3, 0.3)]                    : simultation =  0.8335, theoretical =  0.8337 diff = -0.0001
# leq_d12ky [(3, 0.2)]                    : simultation =  0.7211, theoretical =  0.7216 diff = -0.0004
# leq_d12ky [(3, 0.1)]                    : simultation =  0.5595, theoretical =  0.5600 diff = -0.0005
# leq_d12ky [(3, 0.05)]                   : simultation =  0.4642, theoretical =  0.4648 diff = -0.0005
# leq_d12ky [(3, 0.04)]                   : simultation =  0.4449, theoretical =  0.4454 diff = -0.0005
# leq_d12ky [(3, 0.03)]                   : simultation =  0.4257, theoretical =  0.4261 diff = -0.0004
# leq_d12ky [(3, 0.02)]                   : simultation =  0.4066, theoretical =  0.4071 diff = -0.0005
# leq_d12ky [(3, 0.01)]                   : simultation =  0.3879, theoretical =  0.3884 diff = -0.0005
# leq_d12ky [(3, 0.005)]                  : simultation =  0.3786, theoretical =  0.3791 diff = -0.0005
# leq_d12ky [(3, 0.001)]                  : simultation =  0.3713, theoretical =  0.3719 diff = -0.0005
# leq_d12ky [(3, 0.0001)]                 : simultation =  0.3697, theoretical =  0.3702 diff = -0.0005
# leq_d12ky [(3, -0.0001)]                : simultation =  0.3672, theoretical =  0.3677 diff = -0.0005
# leq_d12ky [(3, -0.001)]                 : simultation =  0.3656, theoretical =  0.3661 diff = -0.0005
# leq_d12ky [(3, -0.005)]                 : simultation =  0.3584, theoretical =  0.3589 diff = -0.0005
# leq_d12ky [(3, -0.01)]                  : simultation =  0.3496, theoretical =  0.3501 diff = -0.0005
# leq_d12ky [(3, -0.02)]                  : simultation =  0.3325, theoretical =  0.3329 diff = -0.0005
# leq_d12ky [(3, -0.03)]                  : simultation =  0.3160, theoretical =  0.3165 diff = -0.0005
# leq_d12ky [(3, -0.04)]                  : simultation =  0.3003, theoretical =  0.3008 diff = -0.0005
# leq_d12ky [(3, -0.05)]                  : simultation =  0.2853, theoretical =  0.2858 diff = -0.0005
# leq_d12ky [(3, -0.1)]                   : simultation =  0.2202, theoretical =  0.2206 diff = -0.0004
# leq_d12ky [(3, -0.2)]                   : simultation =  0.1280, theoretical =  0.1284 diff = -0.0004
# leq_d12ky [(3, -0.3)]                   : simultation =  0.0716, theoretical =  0.0719 diff = -0.0003
# leq_d12ky [(3, -0.4)]                   : simultation =  0.0388, theoretical =  0.0391 diff = -0.0002
# leq_d12ky [(3, -0.5)]                   : simultation =  0.0206, theoretical =  0.0207 diff = -0.0001
# leq_d12ky [(4, 0.5)]                    : simultation =  0.9224, theoretical =  0.9224 diff = -0.0000
# leq_d12ky [(4, 0.4)]                    : simultation =  0.8670, theoretical =  0.8672 diff = -0.0002
# leq_d12ky [(4, 0.3)]                    : simultation =  0.7821, theoretical =  0.7824 diff = -0.0003
# leq_d12ky [(4, 0.2)]                    : simultation =  0.6618, theoretical =  0.6624 diff = -0.0006
# leq_d12ky [(4, 0.1)]                    : simultation =  0.5105, theoretical =  0.5111 diff = -0.0006
# leq_d12ky [(4, 0.05)]                   : simultation =  0.4299, theoretical =  0.4304 diff = -0.0004
# leq_d12ky [(4, 0.04)]                   : simultation =  0.4140, theoretical =  0.4144 diff = -0.0004
# leq_d12ky [(4, 0.03)]                   : simultation =  0.3983, theoretical =  0.3987 diff = -0.0004
# leq_d12ky [(4, 0.02)]                   : simultation =  0.3827, theoretical =  0.3831 diff = -0.0004
# leq_d12ky [(4, 0.01)]                   : simultation =  0.3675, theoretical =  0.3679 diff = -0.0004
# leq_d12ky [(4, 0.005)]                  : simultation =  0.3600, theoretical =  0.3603 diff = -0.0004
# leq_d12ky [(4, 0.001)]                  : simultation =  0.3540, theoretical =  0.3544 diff = -0.0004
# leq_d12ky [(4, 0.0001)]                 : simultation =  0.3527, theoretical =  0.3530 diff = -0.0004
# leq_d12ky [(4, -0.0001)]                : simultation =  0.3521, theoretical =  0.3524 diff = -0.0004
# leq_d12ky [(4, -0.001)]                 : simultation =  0.3507, theoretical =  0.3511 diff = -0.0004
# leq_d12ky [(4, -0.005)]                 : simultation =  0.3448, theoretical =  0.3452 diff = -0.0004
# leq_d12ky [(4, -0.01)]                  : simultation =  0.3375, theoretical =  0.3379 diff = -0.0004
# leq_d12ky [(4, -0.02)]                  : simultation =  0.3233, theoretical =  0.3237 diff = -0.0004
# leq_d12ky [(4, -0.03)]                  : simultation =  0.3094, theoretical =  0.3099 diff = -0.0005
# leq_d12ky [(4, -0.04)]                  : simultation =  0.2960, theoretical =  0.2964 diff = -0.0005
# leq_d12ky [(4, -0.05)]                  : simultation =  0.2830, theoretical =  0.2834 diff = -0.0004
# leq_d12ky [(4, -0.1)]                   : simultation =  0.2244, theoretical =  0.2248 diff = -0.0004
# leq_d12ky [(4, -0.2)]                   : simultation =  0.1357, theoretical =  0.1363 diff = -0.0007
# leq_d12ky [(4, -0.3)]                   : simultation =  0.0785, theoretical =  0.0790 diff = -0.0005
# leq_d12ky [(4, -0.4)]                   : simultation =  0.0438, theoretical =  0.0441 diff = -0.0003
# leq_d12ky [(4, -0.5)]                   : simultation =  0.0237, theoretical =  0.0239 diff = -0.0002
# leq_d12ky [(5, 0.5)]                    : simultation =  0.8943, theoretical =  0.8946 diff = -0.0002
# leq_d12ky [(5, 0.4)]                    : simultation =  0.8284, theoretical =  0.8288 diff = -0.0004
# leq_d12ky [(5, 0.3)]                    : simultation =  0.7351, theoretical =  0.7355 diff = -0.0004
# leq_d12ky [(5, 0.2)]                    : simultation =  0.6138, theoretical =  0.6145 diff = -0.0007
# leq_d12ky [(5, 0.1)]                    : simultation =  0.4742, theoretical =  0.4749 diff = -0.0007
# leq_d12ky [(5, 0.05)]                   : simultation =  0.4038, theoretical =  0.4043 diff = -0.0005
# leq_d12ky [(5, 0.04)]                   : simultation =  0.3900, theoretical =  0.3905 diff = -0.0005
# leq_d12ky [(5, 0.03)]                   : simultation =  0.3764, theoretical =  0.3769 diff = -0.0005
# leq_d12ky [(5, 0.02)]                   : simultation =  0.3630, theoretical =  0.3634 diff = -0.0005
# leq_d12ky [(5, 0.01)]                   : simultation =  0.3497, theoretical =  0.3502 diff = -0.0005
# leq_d12ky [(5, 0.005)]                  : simultation =  0.3432, theoretical =  0.3437 diff = -0.0005
# leq_d12ky [(5, 0.001)]                  : simultation =  0.3380, theoretical =  0.3386 diff = -0.0005
# leq_d12ky [(5, 0.0001)]                 : simultation =  0.3369, theoretical =  0.3374 diff = -0.0005
# leq_d12ky [(5, -0.0001)]                : simultation =  0.3366, theoretical =  0.3371 diff = -0.0005
# leq_d12ky [(5, -0.001)]                 : simultation =  0.3354, theoretical =  0.3359 diff = -0.0005
# leq_d12ky [(5, -0.005)]                 : simultation =  0.3303, theoretical =  0.3308 diff = -0.0005
# leq_d12ky [(5, -0.01)]                  : simultation =  0.3240, theoretical =  0.3245 diff = -0.0005
# leq_d12ky [(5, -0.02)]                  : simultation =  0.3115, theoretical =  0.3121 diff = -0.0005
# leq_d12ky [(5, -0.03)]                  : simultation =  0.2993, theoretical =  0.2999 diff = -0.0006
# leq_d12ky [(5, -0.04)]                  : simultation =  0.2875, theoretical =  0.2881 diff = -0.0006
# leq_d12ky [(5, -0.05)]                  : simultation =  0.2760, theoretical =  0.2765 diff = -0.0005
# leq_d12ky [(5, -0.1)]                   : simultation =  0.2227, theoretical =  0.2234 diff = -0.0006
# leq_d12ky [(5, -0.2)]                   : simultation =  0.1393, theoretical =  0.1400 diff = -0.0008
# leq_d12ky [(5, -0.3)]                   : simultation =  0.0830, theoretical =  0.0837 diff = -0.0006
# leq_d12ky [(5, -0.4)]                   : simultation =  0.0476, theoretical =  0.0480 diff = -0.0004
# leq_d12ky [(5, -0.5)]                   : simultation =  0.0263, theoretical =  0.0266 diff = -0.0002
# leq_d12ky [(6, 0.5)]                    : simultation =  0.8646, theoretical =  0.8651 diff = -0.0005
# leq_d12ky [(6, 0.4)]                    : simultation =  0.7908, theoretical =  0.7913 diff = -0.0005
# leq_d12ky [(6, 0.3)]                    : simultation =  0.6930, theoretical =  0.6935 diff = -0.0004
# leq_d12ky [(6, 0.2)]                    : simultation =  0.5739, theoretical =  0.5747 diff = -0.0008
# leq_d12ky [(6, 0.1)]                    : simultation =  0.4448, theoretical =  0.4457 diff = -0.0009
# leq_d12ky [(6, 0.05)]                   : simultation =  0.3815, theoretical =  0.3822 diff = -0.0007
# leq_d12ky [(6, 0.04)]                   : simultation =  0.3692, theoretical =  0.3699 diff = -0.0007
# leq_d12ky [(6, 0.03)]                   : simultation =  0.3570, theoretical =  0.3578 diff = -0.0008
# leq_d12ky [(6, 0.02)]                   : simultation =  0.3450, theoretical =  0.3458 diff = -0.0008
# leq_d12ky [(6, 0.01)]                   : simultation =  0.3332, theoretical =  0.3340 diff = -0.0008
# leq_d12ky [(6, 0.005)]                  : simultation =  0.3274, theoretical =  0.3282 diff = -0.0008
# leq_d12ky [(6, 0.001)]                  : simultation =  0.3227, theoretical =  0.3235 diff = -0.0008
# leq_d12ky [(6, 0.0001)]                 : simultation =  0.3217, theoretical =  0.3225 diff = -0.0008
# leq_d12ky [(6, -0.0001)]                : simultation =  0.3215, theoretical =  0.3223 diff = -0.0008
# leq_d12ky [(6, -0.001)]                 : simultation =  0.3204, theoretical =  0.3212 diff = -0.0008
# leq_d12ky [(6, -0.005)]                 : simultation =  0.3158, theoretical =  0.3166 diff = -0.0008
# leq_d12ky [(6, -0.01)]                  : simultation =  0.3101, theoretical =  0.3110 diff = -0.0008
# leq_d12ky [(6, -0.02)]                  : simultation =  0.2990, theoretical =  0.2998 diff = -0.0008
# leq_d12ky [(6, -0.03)]                  : simultation =  0.2880, theoretical =  0.2888 diff = -0.0008
# leq_d12ky [(6, -0.04)]                  : simultation =  0.2773, theoretical =  0.2781 diff = -0.0008
# leq_d12ky [(6, -0.05)]                  : simultation =  0.2668, theoretical =  0.2677 diff = -0.0008
# leq_d12ky [(6, -0.1)]                   : simultation =  0.2183, theoretical =  0.2191 diff = -0.0008
# leq_d12ky [(6, -0.2)]                   : simultation =  0.1401, theoretical =  0.1410 diff = -0.0008
# leq_d12ky [(6, -0.3)]                   : simultation =  0.0857, theoretical =  0.0864 diff = -0.0007
# leq_d12ky [(6, -0.4)]                   : simultation =  0.0503, theoretical =  0.0508 diff = -0.0005
# leq_d12ky [(6, -0.5)]                   : simultation =  0.0284, theoretical =  0.0288 diff = -0.0004
# leq_d12ky_midrange [(1, 0.5)]           : simultation =  0.9791, theoretical =  0.9784 diff =  0.0007
# leq_d12ky_midrange [(1, 0.3)]           : simultation =  0.9294, theoretical =  0.9285 diff =  0.0009
# leq_d12ky_midrange [(1, 0.1)]           : simultation =  0.7407, theoretical =  0.7398 diff =  0.0009
# leq_d12ky_midrange [(1, 0.05)]          : simultation =  0.6103, theoretical =  0.6097 diff =  0.0006
# leq_d12ky_midrange [(1, 0.01)]          : simultation =  0.4713, theoretical =  0.4707 diff =  0.0007
# leq_d12ky_midrange [(1, 0.001)]         : simultation =  0.4359, theoretical =  0.4353 diff =  0.0007
# leq_d12ky_midrange [(1, 0.0001)]        : simultation =  0.4323, theoretical =  0.4318 diff =  0.0006
# leq_d12ky_midrange [(1, -0.0001)]       : simultation =  0.3238, theoretical =  0.3236 diff =  0.0002
# leq_d12ky_midrange [(1, -0.001)]        : simultation =  0.3203, theoretical =  0.3201 diff =  0.0001
# leq_d12ky_midrange [(1, -0.01)]         : simultation =  0.2866, theoretical =  0.2865 diff =  0.0001
# leq_d12ky_midrange [(1, -0.05)]         : simultation =  0.1832, theoretical =  0.1828 diff =  0.0003
# leq_d12ky_midrange [(1, -0.1)]          : simultation =  0.1135, theoretical =  0.1136 diff = -0.0002
# leq_d12ky_midrange [(1, -0.3)]          : simultation =  0.0169, theoretical =  0.0169 diff =  0.0000
# leq_d12ky_midrange [(1, -0.5)]          : simultation =  0.0016, theoretical =  0.0016 diff =  0.0000
# var_y_d12_diff [1]                      : simultation =  0.0034, theoretical =  0.0034 diff = -0.0000
# var_y_d12_diff [2]                      : simultation =  0.0068, theoretical =  0.0069 diff = -0.0001
# var_y_d12_diff [3]                      : simultation =  0.0102, theoretical =  0.0103 diff = -0.0001
# var_y_d12_diff [4]                      : simultation =  0.0135, theoretical =  0.0137 diff = -0.0002
# var_y_d12_diff [5]                      : simultation =  0.0169, theoretical =  0.0172 diff = -0.0003
# cov_y_y_d12_diff [1]                    : simultation = -0.0065, theoretical = -0.0065 diff =  0.0000
# cov_y_y_d12_diff [2]                    : simultation = -0.0126, theoretical = -0.0126 diff = -0.0000
# cov_y_y_d12_diff [3]                    : simultation = -0.0184, theoretical = -0.0184 diff = -0.0000
# cov_y_y_d12_diff [4]                    : simultation = -0.0239, theoretical = -0.0238 diff = -0.0001

# %% [markdown]
# # Timings

# %% [markdown]
# ## Theoretical

# %%
tmodel.calc_moments(do_timing=True)
# Out:
# mean_d12ky                    : 0.001000 secs
# mean_d12ky                    : 0.000000 secs
# mean_d12ky                    : 0.000000 secs
# mean_d12ky                    : 0.001001 secs
# mean_d12ky                    : 0.000000 secs
# mean_d12ky                    : 0.000000 secs
# var_d12ky                     : 0.000000 secs
# var_d12ky                     : 0.000000 secs
# var_d12ky                     : 0.000000 secs
# var_d12ky                     : 0.000000 secs
# var_d12ky                     : 0.000000 secs
# var_d12ky                     : 0.000000 secs
# auto_cov_d12y12l              : 0.000000 secs
# auto_cov_d12y12l              : 0.000000 secs
# auto_cov_d12y12l              : 0.001001 secs
# auto_cov_d12y12l              : 0.000000 secs
# auto_cov_d12y12l              : 0.000000 secs
# auto_cov_d12y12l              : 0.000000 secs
# auto_cov_d12y12l              : 0.001001 secs
# auto_cov_d12y12l              : 0.000000 secs
# frac_auto_cov_d12y1l          : 0.000000 secs
# frac_auto_cov_d12y1l          : 0.000000 secs
# frac_auto_cov_d12y1l          : 0.000000 secs
# frac_auto_cov_d12y1l          : 0.000000 secs
# frac_auto_cov_d12y1l          : 0.000000 secs
# frac_auto_cov_d12y1l          : 0.001001 secs
# frac_auto_cov_d12y1l          : 0.000000 secs
# frac_auto_cov_d12y1l          : 0.000000 secs
# frac_auto_cov_d12y1l          : 0.001001 secs
# frac_auto_cov_d12y1l          : 0.000000 secs
# frac_auto_cov_d12y1l          : 0.000000 secs
# kurt_d12ky                    : 0.000999 secs
# kurt_d12ky                    : 0.001000 secs
# kurt_d12ky                    : 0.002002 secs
# kurt_d12ky                    : 0.002002 secs
# kurt_d12ky                    : 0.002002 secs
# kurt_d12ky                    : 0.003002 secs
# leq_d1ky                      : 0.001001 secs
# leq_d1ky_midrange             : 0.008006 secs
# leq_d12ky_midrange            : 0.087702 secs
# var_y_d12_diff                : 0.000000 secs
# var_y_d12_diff                : 0.000000 secs
# var_y_d12_diff                : 0.000000 secs
# var_y_d12_diff                : 0.000000 secs
# var_y_d12_diff                : 0.000000 secs
# var_y_d12_diff                : 0.000000 secs
# cov_y_y_d12_diff              : 0.000000 secs
# cov_y_y_d12_diff              : 0.000000 secs
# cov_y_y_d12_diff              : 0.000000 secs
# cov_y_y_d12_diff              : 0.000000 secs
# cov_y_y_d12_diff              : 0.000000 secs

# %% [markdown]
# ## Simulation

# %%
model.calc_moments(do_timing=True)
# Out:
# mean_d12ky                    : 0.171320 secs
# mean_d12ky                    : 0.171912 secs
# mean_d12ky                    : 0.156282 secs
# mean_d12ky                    : 0.171912 secs
# mean_d12ky                    : 0.156283 secs
# mean_d12ky                    : 0.158557 secs
# auto_cov_d12y12l              : 0.481930 secs
# auto_cov_d12y12l              : 0.469100 secs
# auto_cov_d12y12l              : 0.469037 secs
# auto_cov_d12y12l              : 0.437795 secs
# auto_cov_d12y12l              : 0.437767 secs
# auto_cov_d12y12l              : 0.406581 secs
# auto_cov_d12y12l              : 0.406536 secs
# auto_cov_d12y12l              : 0.392637 secs
# frac_auto_cov_d12y1l          : 0.500324 secs
# frac_auto_cov_d12y1l          : 0.499841 secs
# frac_auto_cov_d12y1l          : 0.515807 secs
# frac_auto_cov_d12y1l          : 0.500242 secs
# frac_auto_cov_d12y1l          : 0.500323 secs
# frac_auto_cov_d12y1l          : 0.484736 secs
# frac_auto_cov_d12y1l          : 0.484700 secs
# frac_auto_cov_d12y1l          : 0.507076 secs
# frac_auto_cov_d12y1l          : 0.494270 secs
# frac_auto_cov_d12y1l          : 0.484542 secs
# frac_auto_cov_d12y1l          : 0.500339 secs
# leq_d1ky                      : 1.250508 secs
# leq_d1ky_midrange             : 0.890814 secs
# leq_d12ky                     : 1.203339 secs
# leq_d12ky                     : 1.078395 secs
# leq_d12ky                     : 1.000211 secs
# leq_d12ky                     : 0.922071 secs
# leq_d12ky                     : 0.859666 secs
# leq_d12ky                     : 0.797690 secs
# leq_d12ky_midrange            : 0.969492 secs
# var_y_d12_diff                : 0.255017 secs
# var_y_d12_diff                : 0.230946 secs
# cov_y_y_d12_diff              : 4.456097 secs
# cov_y_y_d12_diff              : 4.469655 secs

# %% [markdown]
# # Arrival probabilities from mass points

# %% [markdown]
# **Step 1:** Setup with $\sigma_{\phi}^2 = \sigma_{\xi}^2 = \sigma_{\epsilon}^2 = 0$

# %%
fmodel = HighFreqIncProcessClass(name='check_ps',par={'use_equal_weighting':True,'use_theoretical':False,'sigma_xi':0.0,'sigma_phi':0.0,'sigma_epsilon':0.0})
fmodel.set_specs()
fmodel.setup_simulation()
fmodel.simulate()

# %% [markdown]
# **Step 2:** Functions for calculating fractions

# %%
from numba import njit

@njit
def frac(y,k,value,eps=1e-6):
    num = 0.0
    tot = 0.0
    for i in range(y.shape[0]):
        for t in range(k,y.shape[1]):
            dky = y[i,t]-y[i,t-k]
            tot += 1.0
            if np.abs(dky-value) < eps: 
                num += 1.0
                    
    return num/tot

@njit
def frac_cond(y,k,value,eps=1e-6):
    num = 0.0
    tot = 0.0
    for i in range(y.shape[0]):
        for t in range(12+k,y.shape[1]):
            dky = y[i,t] - y[i,t-k]
            d12y_lag = y[i,t-k] - y[i,t-k-12]
            if np.abs(d12y_lag - 0.0) < eps: 
                tot += 1.0
                if np.abs(dky - value) < eps:
                    num += 1.0
                    
    return num/tot

# %% [markdown]
# **Step 3:** Check moment calculations

# %%
par = fmodel.par
sim = fmodel.sim

frac_zero = lambda k: (1-par.p_psi)**k*((1-par.p_xi)**2+par.p_xi**2)*(1-par.p_phi)**k*(1-par.p_eta)**2
for k in range(1,5):
    frac_zero_sim = frac(sim.y,12*k,0.0)
    print(f'frac_zero (k = {12*k}): simulation = {frac_zero_sim:.4f}, theoretical = {frac_zero(12*k):.4f}')
    
print('')
frac_mu_phi = lambda k: (1-par.p_psi)**k*((1-par.p_xi)**2+par.p_xi**2)*k*par.p_phi*(1-par.p_phi)**(k-1)*(1-par.p_eta)**2
for k in range(1,5):
    frac_mu_phi_sim = frac(sim.y,12*k,par.mu_phi)
    print(f'frac_mu_phi (k = {12*k}): simulation = {frac_mu_phi_sim:.4f}, theoretical = {frac_mu_phi(12*k):.4f}')
    
print('')    
frac_mu_xi = lambda k: (1-par.p_psi)**k*par.p_xi*(1-par.p_xi)*(1-par.p_phi)**k*(1-par.p_eta)**2
for k in range(1,5):
    frac_mu_xi_sim = frac(sim.y,12*k,par.mu_xi)
    print(f'frac_mu_xi (k = {12*k}): simulation = {frac_mu_xi_sim:.6f}, theoretical = {frac_mu_xi(12*k):.6f}')    
    
print('')    
base_cond = lambda k: (1-par.p_psi)**k*(1-par.p_phi)**k*(1-par.p_eta)/(par.p_xi**2+(1-par.p_xi)**2)
frac_zero_cond = lambda k: base_cond(k)*(par.p_xi**3+(1-par.p_xi)**3)
for k in range(1,5):
    frac_zero_cond_sim = frac_cond(sim.y,12*k,0.0)
    print(f'frac_zero_cond (k = {12*k}): simulation = {frac_zero_cond_sim:.6f}, theoretical = {frac_zero_cond(12*k):.6f}')
    
print('')    
frac_mu_xi_cond = lambda k: base_cond(k)*par.p_xi*(1-par.p_xi)**2
for k in range(1,5):
    frac_mu_xi_cond_sim = frac_cond(sim.y,12*k,par.mu_xi)
    print(f'frac_mu_xi_cond (k = {12*k}): simulation = {frac_mu_xi_cond_sim:.6f}, theoretical = {frac_mu_xi_cond(12*k):.6f}')    
    
print('')    
frac_mu_xi_neg_cond = lambda k: base_cond(k)*(1-par.p_xi)*par.p_xi**2
for k in range(1,5):
    frac_mu_xi_xi_neg_sim = frac_cond(sim.y,12*k,-par.mu_xi)
    print(f'frac_mu_xi_neg_cond (k = {12*k}): simulation = {frac_mu_xi_xi_neg_sim:.6f}, theoretical = {frac_mu_xi_neg_cond(12*k):.6f}')
# Out:
# frac_zero (k = 12): simulation = 0.0941, theoretical = 0.0940
# frac_zero (k = 24): simulation = 0.0144, theoretical = 0.0144
# frac_zero (k = 36): simulation = 0.0022, theoretical = 0.0022
# frac_zero (k = 48): simulation = 0.0003, theoretical = 0.0003
#
# frac_mu_phi (k = 12): simulation = 0.1255, theoretical = 0.1254
# frac_mu_phi (k = 24): simulation = 0.0384, theoretical = 0.0383
# frac_mu_phi (k = 36): simulation = 0.0088, theoretical = 0.0088
# frac_mu_phi (k = 48): simulation = 0.0018, theoretical = 0.0018
#
# frac_mu_xi (k = 12): simulation = 0.008110, theoretical = 0.008115
# frac_mu_xi (k = 24): simulation = 0.001239, theoretical = 0.001239
# frac_mu_xi (k = 36): simulation = 0.000189, theoretical = 0.000189
# frac_mu_xi (k = 48): simulation = 0.000032, theoretical = 0.000029
#
# frac_zero_cond (k = 12): simulation = 0.118759, theoretical = 0.118526
# frac_zero_cond (k = 24): simulation = 0.018123, theoretical = 0.018089
# frac_zero_cond (k = 36): simulation = 0.002712, theoretical = 0.002761
# frac_zero_cond (k = 48): simulation = 0.000405, theoretical = 0.000421
#
# frac_mu_xi_cond (k = 12): simulation = 0.010275, theoretical = 0.010300
# frac_mu_xi_cond (k = 24): simulation = 0.001577, theoretical = 0.001572
# frac_mu_xi_cond (k = 36): simulation = 0.000242, theoretical = 0.000240
# frac_mu_xi_cond (k = 48): simulation = 0.000042, theoretical = 0.000037
#
# frac_mu_xi_neg_cond (k = 12): simulation = 0.000896, theoretical = 0.000896
# frac_mu_xi_neg_cond (k = 24): simulation = 0.000128, theoretical = 0.000137
# frac_mu_xi_neg_cond (k = 36): simulation = 0.000017, theoretical = 0.000021
# frac_mu_xi_neg_cond (k = 48): simulation = 0.000002, theoretical = 0.000003

# %% [markdown]
# **Step 4:** Infer parameters

# %%
p_phi = frac(sim.y,12,par.mu_phi) / ( 12*frac(sim.y,12,0.0) + frac(sim.y,12,par.mu_phi))
print(f'p_phi: {p_phi:.4f} (estimated) vs. {par.p_phi:.4f} (true)')

p_xi = frac_cond(sim.y,12,-par.mu_xi) / ( frac_cond(sim.y,12,par.mu_xi) + frac_cond(sim.y,12,-par.mu_xi) )
print(f'p_xi:  {p_xi:.4f} (estimated) vs. {par.p_xi:.4f} (true)')

p_psi = 1-( frac(sim.y,24,0.0) / frac(sim.y,12,0.0) )**(1/12) / (1-par.p_phi)
print(f'p_psi: {p_psi:.4f} (estimated) vs. {par.p_psi:.4f} (true)')

p_eta = 1-(frac(sim.y,12,0.0) / ( (1-par.p_psi)**12 * ((1-par.p_xi)**2+par.p_xi**2) * (1-par.p_phi)**12) )**(1/2)
print(f'p_xi:  {p_eta:.4f} (estimated) vs. {par.p_eta:.4f} (true)')
# Out:
# p_phi: 0.1000 (estimated) vs. 0.1000 (true)
# p_xi:  0.0802 (estimated) vs. 0.0800 (true)
# p_psi: 0.0499 (estimated) vs. 0.0500 (true)
# p_xi:  0.1497 (estimated) vs. 0.1500 (true)

# %% [markdown]
# # Approximatin of conditional CDF

# %%
testmodel = tmodel.copy(name='testmodel')
testmodel.specs = {
    'kurt_d12ky':[{'args':k} for k in [1]],   
    'leq_d12ky_midrange': [{'args':(1,eta)} for eta in [1e-4,0.25,0.50]]
    }

for wmin in [1e-8,1e-7,1e-6,1e-5,1e-4]:
    print(f'wmin = {wmin}')
    testmodel.par.wmin = wmin
    # %timeit testmodel.calc_moments()
    testmodel.show_moments()
    print('')
# Out:
# wmin = 1e-08
# 92.7 ms ± 160 µs per loop (mean ± std. dev. of 7 runs, 10 loops each)
# kurt_d12ky [1]                          :   3.59610296
# leq_d12ky_midrange [(1, 0.0001)]        :   0.43206344
# leq_d12ky_midrange [(1, 0.25)]          :   0.90434631
# leq_d12ky_midrange [(1, 0.5)]           :   0.97914860
#
# wmin = 1e-07
# 54.2 ms ± 911 µs per loop (mean ± std. dev. of 7 runs, 10 loops each)
# kurt_d12ky [1]                          :   3.59571032
# leq_d12ky_midrange [(1, 0.0001)]        :   0.43202797
# leq_d12ky_midrange [(1, 0.25)]          :   0.90427788
# leq_d12ky_midrange [(1, 0.5)]           :   0.97905736
#
# wmin = 1e-06
# 27.8 ms ± 767 µs per loop (mean ± std. dev. of 7 runs, 10 loops each)
# kurt_d12ky [1]                          :   3.59222405
# leq_d12ky_midrange [(1, 0.0001)]        :   0.43175846
# leq_d12ky_midrange [(1, 0.25)]          :   0.90374612
# leq_d12ky_midrange [(1, 0.5)]           :   0.97835587
#
# wmin = 1e-05
# 12.4 ms ± 263 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# kurt_d12ky [1]                          :   3.56483422
# leq_d12ky_midrange [(1, 0.0001)]        :   0.42988106
# leq_d12ky_midrange [(1, 0.25)]          :   0.89978899
# leq_d12ky_midrange [(1, 0.5)]           :   0.97307450
#
# wmin = 0.0001
# 5.01 ms ± 239 µs per loop (mean ± std. dev. of 7 runs, 100 loops each)
# kurt_d12ky [1]                          :   3.35942910
# leq_d12ky_midrange [(1, 0.0001)]        :   0.41815023
# leq_d12ky_midrange [(1, 0.25)]          :   0.87361154
# leq_d12ky_midrange [(1, 0.5)]           :   0.93943917
